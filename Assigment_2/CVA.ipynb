# %%
from os import listdir
from os.path import isfile, join
from matplotlib import pyplot as plt
import numpy as np

import cv2

from functions import *

# %%
IMG_PATH = 'Images/train'
ID = 2

imageFiles = [f for f in listdir(IMG_PATH) if isfile(join(IMG_PATH, f))]

image = cv2.imread(join(IMG_PATH, imageFiles[ID]))
plt.imshow(image,interpolation='nearest')
plt.scatter(x=256,y=256)
plt.show()

b,g,r = (image[256, 256])
print('Center color point:',b,g,r)
# Out:
# Center color point: 237 209 115

# %%
range = 25

# upperBound = np.array([b+range,g+range,r+range])
# lowerBound = np.array([b-range,g-range,r-range])
# poolDetection = cv2.inRange(image,lowerBound,upperBound)

# plt.imshow(poolDetection,interpolation='nearest')
# plt.show()

# %%
for c in range(3):
    print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10208/223792754.py in <module>
# ----> 1 for c in range(3):
#       2     print(c)
#
# TypeError: 'int' object is not callable
